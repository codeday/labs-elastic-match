# %%
"""Build the combined data dictionary and the student placement dictionary"""
import json

project_docs = open("./mentor_index_dump_2", "r", encoding="utf-8")
project_size_data = json.load(open("./mentors_size_data.json", "r", encoding="utf-8"))
project_size_dict = {project["proj_id"]: project["proj_size_remaining"] for project in project_size_data}

all_project_data = {}
student_placements = {}
for line in project_docs:
    project_doc = json.loads(line)
    if project_doc["id"] == 'recRJGXhTr9lEq1tO':
        continue
    id_ = project_doc["id"]
    proj_size = project_size_dict[id_]
    if proj_size == 0:
        continue
    all_project_data[id_] = project_doc
    all_project_data[id_]["proj_size_remaining"] = proj_size
    all_project_data[id_]["num_first_choice"] = len([choice for choice in project_doc.get('listStudentsSelected') if choice["choice"] == 1])

    student_placements[id_] = {"students": [], "proj_capacity": project_size_dict[id_]}
print(all_project_data)
# Out:
# {'recVXa5uqnQ8MpDzJ': {'numStudentsSelected': 5, 'backgroundRural': True, 'timezone': -4, 'proj_tags': ['Frontend', 'Data'], 'bio': 'I am a passionate software developer with extensive practical experience with Windows app development using C#, macOS app development using Swift, and in more programming languages that I can even count. I have worked at eFlex Systems and Oakland University. I grew up in the Greater Detroit Area in the United States of America. Learn more about me on my LinkedIn: https://www.linkedin.com/in/william-kent-13847711a/ (pronouns: he/his)', 'proj_description': 'Create a spreadsheet program for Windows 10 using C#, Windows Forms, and .NET 5.', 'preferStudentUnderRep': 0, 'okExtended': True, 'okTimezoneDifference': False, 'preferToolExistingKnowledge': True, 'name': 'William Kent', 'company': 'Sunburst Solutions', 'id': 'recVXa5uqnQ8MpDzJ', 'track': 'Beginner', 'listStudentsSelected': [{'student_id': 'recJHT6W7cvgVB3PI', 'choice': 2}, {'student_id': 'recAEjPjzBpOmoFi4', 'choice': 4}, {'student_id': 'recpNC7Da4rzGErs9', 'choice': 2}, {'student_id': 'rec4lUePnxyU7t8Fj', 'choice': 2}], 'proj_size_remaining': 3, 'num_first_choice': 0}, 'recwHylW2G0horHUu': {'numStudentsSelected': 10, 'backgroundRural': False, 'timezone': -4, 'proj_tags': ['Web Dev', 'Research', 'Frontend'], 'bio': "Saharsh is a web developer that's a rising senior from Massachusetts. He is passionate about education and personal finance. If he's not reading a book or trying to learn something new, then he's probably out on a run. Learn more about them on their LinkedIn: https://www.linkedin.com/in/saharsh-yeruva/", 'proj_description': 'A chrome extension that looks at all the images on a webpage. If there is an image that does not have an alt tag, use ml to generate one so that screen-readers can actually recognize it.', 'preferStudentUnderRep': 0, 'okExtended': False, 'okTimezoneDifference': False, 'preferToolExistingKnowledge': True, 'name': 'Saharsh Yeruva', 'company': 'SRND', 'id': 'recwHylW2G0horHUu', 'track': 'Beginner', 'listStudentsSelected': [{'student_id': 'recbTeOuojoKhoM26', 'choice': 1}, {'student_id': 'recQfzcvaHNwTbkVc', 'choice': 7}, {'student_id': 'reclPikFOrRPlrGRe', 'choice': 1}, {'student_id': 'recTOWyuTZm8cU2tO', 'choice': 4}, {'student_id': 'reccWfSRl5mVkoCf8', 'choice': 4}, {'student_id': 'rec3GRGpffEsd8xF7', 'choice': 4}, {'student_id': 'recAEjPjzBpOmoFi4', 'choice': 6}, {'student_id': 'recNuyk7xsT2aL0MW', 'choice': 1}, {'student_id': 'recpNC7Da4rzGErs9', 'choice': 3}, {'student_id': 'rec4lUePnxyU7t8Fj', 'choice': 3}], 'proj_size_remaining': 3, 'num_first_choice': 3}, 'rec8VbKfxjLtIQnal': {'numStudentsSelected': 17, 'backgroundRural': False, 'timezone': -7, 'proj_tags': ['Frontend', 'Web Dev'], 'bio': 'Evan is   with  years of experience, working on  at . They grew up in Fountain Hills / AZ / USA. Learn more about them on their LinkedIn: https://www.linkedin.com/in/evanhao/', 'proj_description': 'Create a website to play chess (depending on how difficult this is, either make it so that other people can connect with you and play, or make it so chess is only playable on the same computer). Also, there will be other options included such as having clocks for each player, choice of playing as white or black, etc. The design will require HTML, CSS, and Javascript use.', 'preferStudentUnderRep': 1, 'okExtended': False, 'okTimezoneDifference': True, 'preferToolExistingKnowledge': False, 'name': 'Evan Hao', 'id': 'rec8VbKfxjLtIQnal', 'track': 'Beginner', 'listStudentsSelected': [{'student_id': 'reclPikFOrRPlrGRe', 'choice': 8}, {'student_id': 'recJHT6W7cvgVB3PI', 'choice': 4}, {'student_id': 'recIi3OmKnE8uYMGC', 'choice': 4}, {'student_id': 'rec3GRGpffEsd8xF7', 'choice': 2}, {'student_id': 'rec64kqc6YAH49JFB', 'choice': 4}, {'student_id': 'recNtTiLlmeL7bVkR', 'choice': 5}, {'student_id': 'recodspow4mznvJjm', 'choice': 6}, {'student_id': 'recO9G2RrNAUKqC4z', 'choice': 3}, {'student_id': 'recpNid3frtQ4dciR', 'choice': 1}, {'stu ...

# %%
# Build analysis data
# # first choice votes for every project
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib import colors
#
#
# first_choices = {}
# for proj_id, proj_data in all_project_data.items():
#     try:
#         picks = [choice for choice in proj_data.get('listStudentsSelected') if choice["choice"] == 1]
#         first_choices[proj_id] = {"first_choices": picks, "num": len(picks)}
#     except:
#         pass
# print(first_choices)
#
#
# num_zero = 0
# num_one = 0
# num_two = 0
# num_three = 0
# num_first_choice = 0
#
# for k, proj in first_choices.items():
#     num_first_choice += proj["num"]
#     if proj["num"] == 0:
#         num_zero += 1
#     if proj["num"] == 1:
#         num_one += 1
#     if proj["num"] == 2:
#         num_two += 2
#     if proj["num"] > 3:
#         num_three += 3
#
# fig, axs = plt.subplots()
# N, bins, patches = axs.hist([choice["num"] for k, choice in first_choices.items()])
# fracs = N / N.max()
# norm = colors.Normalize(fracs.min(), fracs.max())
# for thisfrac, thispatch in zip(fracs, patches):
#     color = plt.cm.viridis(norm(thisfrac))
#     thispatch.set_facecolor(color)
perfect_first_choice_project_count = 0
less_first_choice_project_count = 0
greater_first_choice_project_count = 0
for k, project in all_project_data.items():
    if project.get('proj_size_remaining') != 3:
        if project.get('proj_size_remaining') == project.get('num_first_choice'):
            perfect_first_choice_project_count += 1
        if project.get('proj_size_remaining') > project.get('num_first_choice'):
            less_first_choice_project_count += 1
        if project.get('proj_size_remaining') < project.get('num_first_choice'):
            greater_first_choice_project_count += 1
students = []
for i in [[student["student_id"] for student in project["listStudentsSelected"]] for k, project in all_project_data.items()]:
    for j in i:
        students.append(j)

num_students = set(students)

# %%
""" Create final matches dict

Ok so here's the plan:
1. Start with projects that are 'perfect' - the same number of first choice votes as students needed. Assign students
    to those by adding their information to the saved project dictionary. Remove those student's votes from all projects
    to avoid duplicates. Projects can also be removed from the list for simplicity - Maybe not?.
2. Then, assign first choice votes to students on projects with less first choice votes than the projects need. Also
    remove those students votes from other projects. Decrement `proj_size_remaining`.
3. Then, assign second, third, and more choice votes as needed until `proj_size_remaining` = 0, them remove the project.
    Do this in order, all second place votes, third place votes, and so on so that students get their lowest possible
    choice. If multiple students are tied, be sure to assign based on which student has the fewest votes left in other
    projects. Also remember to remove the student from all other projects when their vote is saved.
4. Once all projects with less first choice votes than needed are dealt with, we are left with only projects that
    started with more than enough first choice votes. These should have exactly the correct number of first choice votes
    left due to how students have been removed. Assign these students, and complain loudly if something is wrong.

The data used is a dict called `all_project_data` that contains all projects with the project data, student choices, `num_first_choice` (for convenience), and  `proj_size_remaining`,
```json
all_project_data = {
  "<proj_id>": {
    <project information from elastic>,
    "listStudentsSelected": [{"student_id": <student_id>, "choice": 1}, ...],
    "proj_size_remaining": 5 ,
    "num_first_choice": 3,
  },
  ...
}
```

as well as a dict called `student_placements`  that will be used to store the final placements:
```json
student_placements = {
  "<proj_id>": {
    "students": ["<student_id>", ...],
    "proj_capacity": 5  # Allows for double checking later
  },
  ...
}
```
"""
from typing import Tuple, Union
from copy import deepcopy


def count_student_votes(project_data_dict: dict, student_id: str) -> int:
    student_votes = 0
    for k, project in project_data_dict.items():
        student_votes += len([student for student in project['listStudentsSelected'] if student["student_id"] == student_id])
    return student_votes


def remove_student(project_data_dict: dict, student_id: str) -> dict:
    """Removes the provided student ID from the all_project_data dict"""
    for id, project in project_data_dict.items():
        project_data_dict[id]["listStudentsSelected"] = [
            student
            for student in project["listStudentsSelected"]
            if student["student_id"] != student_id
        ]
    return project_data_dict


def place_student(
    project_data_dict: dict, placement_dict: dict, project_id: str, student_id: str
) -> Tuple[dict, dict]:
    """Places the student in the project, handles removing the student from project data as well as decrementing
    needed students and placing needed info in placement_dict. Also removes completed projects from the project data and
    decrements "num_first_choice" if needed.

    :return project_data_dict, placement_dict
    """
    choice = 0
    for student in project_data_dict[project_id]["listStudentsSelected"]:
        if student["student_id"] == student_id:
            choice = student["choice"]

    placement_dict[project_id]["students"].append(student_id)
    project_data_dict = remove_student(project_data_dict, student_id)
    project_data_dict[project_id]["proj_size_remaining"] -= 1
    if choice == 1:
        project_data_dict[project_id]["num_first_choice"] -= 1

    if project_data_dict[project_id]["proj_size_remaining"] <= 0:
        del project_data_dict[project_id]

    return project_data_dict, placement_dict


def place_students_of_choice(
    project_data_dict: dict,
    placement_dict: dict,
    project_id: str,
    choice: int,
    num: int,
) -> Tuple[dict, dict]:
    """Will place the first `num` students of choice `choice` on a project, or will place until all students of `choice`
    have been placed. Chooses between valid students by picking those who appear the least frequently in other remaining
    votes."""

    counter = 0
    modified_project_data_dict = deepcopy(project_data_dict)
    for student in project_data_dict[project_id]["listStudentsSelected"]:
        if counter >= num:
            break
        if student["choice"] == choice:
            place_student(modified_project_data_dict, placement_dict, project_id, student["student_id"])
            counter += 1
            print(f"added to {project_id} for a total of {counter}")
        if project_data_dict[project_id] is None:
            break
    return modified_project_data_dict, student_placements

def place_students_of_choice_balanced(
    project_data_dict: dict,
    placement_dict: dict,
    project_id: str,
    choice: list,
    num: int,
) -> Tuple[dict, dict]:
    """Will place the first `num` students of choice `choice` on a project, or will place until all students of `choice`
    have been placed. Chooses between valid students by picking those who appear the least frequently in other remaining
    votes."""

    counter = 0
    matching_student_frequency = sorted({student["student_id"]: count_student_votes(project_data_dict, student["student_id"])
                            for student in project_data_dict[project_id]["listStudentsSelected"]
                            if student["choice"] in choice}.items(), key=lambda x: x[1])
    print(matching_student_frequency)
    for i in range(num):
        if i >= len(matching_student_frequency):
            break
        project_data_dict, placement_dict = place_student(project_data_dict, placement_dict, project_id, matching_student_frequency[i][0])

    # for student in project_data_dict[project_id]["listStudentsSelected"]:
    #     if counter >= num:
    #         break
    #     if student["choice"] == choice:
    #         place_student(modified_project_data_dict, placement_dict, project_id, student["student_id"])
    #         counter += 1
    #         print(f"added to {project_id} for a total of {counter}")
    #     if project_data_dict[project_id] is None:
    #         break
    return project_data_dict, placement_dict


starting_students = []
for i in [[student["student_id"] for student in project["listStudentsSelected"]] for k, project in all_project_data.items()]:
    for j in i:
        starting_students.append(j)
num_starting_students = set(starting_students)


# Do step 1
for id, project in all_project_data.items():
    if project["proj_size_remaining"] == project["num_first_choice"]:
        all_project_data, student_placements = place_students_of_choice(all_project_data, student_placements, id, 1, project["proj_size_remaining"])

# Do step 2
for id, project in all_project_data.items():
    if project["proj_size_remaining"] >= project["num_first_choice"]:
        print("Project is smaller than first choice")
        all_project_data, student_placements = place_students_of_choice(all_project_data, student_placements, id, 1, project["proj_size_remaining"])

# Do step 3
_all_project_data = deepcopy(all_project_data)
for id, project in _all_project_data.items():
    if project["proj_size_remaining"] >= project["num_first_choice"]:
        all_project_data, student_placements = place_students_of_choice_balanced(all_project_data, student_placements, id, [2,15], project["proj_size_remaining"])


# Do step 4
_all_project_data = deepcopy(all_project_data)
for id, project in _all_project_data.items():
    all_project_data, student_placements = place_students_of_choice_balanced(all_project_data, student_placements, id, [1], project["proj_size_remaining"])


_all_project_data = deepcopy(all_project_data)
for id, project in _all_project_data.items():
    all_project_data, student_placements = place_students_of_choice_balanced(all_project_data, student_placements, id, [2,15], project["proj_size_remaining"])


# Check for issues
count = 0
for id, project in all_project_data.items():
     if project["proj_size_remaining"] >= len(project["listStudentsSelected"]):
         count += project["proj_size_remaining"] - len(project["listStudentsSelected"])
         print("Uh oh!" + str(count))

students = []
for i in [[student for student in project["students"]] for k, project in student_placements.items()]:
    for j in i:
        students.append(j)
num_students = set(students)
print(f"Number of Students assigned: {len(students)}/{len(num_students)}. Starting students: {len(num_starting_students)}")
print("lol")
# Out:
# added to recwHylW2G0horHUu for a total of 1
# added to recwHylW2G0horHUu for a total of 2
# added to recwHylW2G0horHUu for a total of 3
# added to rec8VbKfxjLtIQnal for a total of 1
# added to rec8VbKfxjLtIQnal for a total of 2
# added to rec8VbKfxjLtIQnal for a total of 3
# added to recj1nYmJ5Lfjoi1f for a total of 1
# added to recj1nYmJ5Lfjoi1f for a total of 2
# added to recj1nYmJ5Lfjoi1f for a total of 3
# added to rec03wlXtIFNFy8lR for a total of 1
# added to rec03wlXtIFNFy8lR for a total of 2
# added to rec03wlXtIFNFy8lR for a total of 3
# added to rec6nhvumluQP4zHF for a total of 1
# added to rec6nhvumluQP4zHF for a total of 2
# added to rec6nhvumluQP4zHF for a total of 3
# added to recSdpegXLOpcbgOz for a total of 1
# added to recSdpegXLOpcbgOz for a total of 2
# added to recSdpegXLOpcbgOz for a total of 3
# added to recyR7GZ1mFBKt7cd for a total of 1
# added to recyR7GZ1mFBKt7cd for a total of 2
# added to recyR7GZ1mFBKt7cd for a total of 3
# added to recfRVcYvECgJ0BlY for a total of 1
# added to recfRVcYvECgJ0BlY for a total of 2
# added to recfRVcYvECgJ0BlY for a total of 3
# added to recaMlxDylhMQKmjx for a total of 1
# added to recaMlxDylhMQKmjx for a total of 2
# added to recaMlxDylhMQKmjx for a total of 3
# added to rec29WHzDZweK5MSX for a total of 1
# added to rec29WHzDZweK5MSX for a total of 2
# added to rec29WHzDZweK5MSX for a total of 3
# added to reclyXfRCjMAtSVn0 for a total of 1
# added to reclyXfRCjMAtSVn0 for a total of 2
# added to reclyXfRCjMAtSVn0 for a total of 3
# added to rec89XDCAICl8B1hq for a total of 1
# added to rec89XDCAICl8B1hq for a total of 2
# added to rec89XDCAICl8B1hq for a total of 3
# added to recrWyOBCt7mdCVUq for a total of 1
# added to recrWyOBCt7mdCVUq for a total of 2
# added to recrWyOBCt7mdCVUq for a total of 3
# added to recMUDc4QanD1bUSv for a total of 1
# added to recMUDc4QanD1bUSv for a total of 2
# added to recMUDc4QanD1bUSv for a total of 3
# added to recdSw62Zqu2k2DR4 for a total of 1
# added to recdSw62Zqu2k2DR4 for a total of 2
# added to recdSw62Zqu2k2DR4 for a total of 3
# added to recp2mIKDr0poiZq6 for a total of 1
# added to recp2mIKDr0poiZq6 for a total of 2
# added to recp2mIKDr0poiZq6 for a total of 3
# added to recOOUSWjq5p10UsK for a total of 1
# added to recOOUSWjq5p10UsK for a total of 2
# added to recOOUSWjq5p10UsK for a total of 3
# added to rect5SnJ7nuCVSl3c for a total of 1
# added to rect5SnJ7nuCVSl3c for a total of 2
# added to rect5SnJ7nuCVSl3c for a total of 3
# added to recFGPIXS8vd9jmsm for a total of 1
# added to recFGPIXS8vd9jmsm for a total of 2
# added to recFGPIXS8vd9jmsm for a total of 3
# added to recGHcFpPJBLqVi6A for a total of 1
# added to recGHcFpPJBLqVi6A for a total of 2
# added to recGHcFpPJBLqVi6A for a total of 3
# added to recAmfKOaD2aXtpnB for a total of 1
# added to recAmfKOaD2aXtpnB for a total of 2
# added to recAmfKOaD2aXtpnB for a total of 3
# added to reczqDxIOXArZyOpx for a total of 1
# added to reczqDxIOXArZyOpx for a total of 2
# added to reczqDxIOXArZyOpx for a total of 3
# added to reccsF566FHphJPyR for a total of 1
# added to reccsF566FHphJPyR for a total of 2
# added to reccsF566FHphJPyR for a total of 3
# added to rec5I2EKeNW7vFCCM for a total of 1
# added to rec5I2EKeNW7vFCCM for a total of 2
# added to rec5I2EKeNW7vFCCM for a total of 3
# added to recv8hX8AL9ISzlhU for a total of 1
# added to recv8hX8AL9ISzlhU for a total of 2
# added to recv8hX8AL9ISzlhU for a total of 3
# added to recFtnrM4ZyO7lYBG for a total of 1
# added to recFtnrM4ZyO7lYBG for a total of 2
# added to recFtnrM4ZyO7lYBG for a total of 3
# added to rec6sNBGBQIeZmEQP for a total of 1
# added to rec6sNBGBQIeZmEQP for a total of 2
# added to rec6sNBGBQIeZmEQP for a total of 3
# Project is smaller than first choice
# Project is smaller than first choice
# added to rec8TCzwcd1NKCuPj for a total of 1
# added to rec8TCzwcd1NKCuPj for a total of 2
# Project is smaller than first choice
# added to recxlqfxamLaT5EMl for a total of 1
# added to recxlqfxamLaT5EMl for a total of 2
# Project is smaller than first choice
# added to recCJ1mlBbhB79F2Z for a total of 1
# added to recCJ1mlBbhB79F2Z for a total of 2
# Project is smaller than first choice
# added to recRfHH9SVG5NaQ8V for a total of 1
# added to recRfHH9SVG5NaQ8V for a total of 2
# Project is smaller than first choice
# added to recSESsXoBHuEEYTs for a total of 1
# added to recSESsXoBHuEEYTs for a total of 2
# Project is smaller than first choice
# Project is smaller than first choice
# Project is smaller than first choice
# added to recNRlhAmOOUy32V3 for a total of 1
# Project is smaller than first choice
# added to recqWu6v4nQDOBt6i for a total of 1
# added to recqWu6v4nQDOBt6i for a total of 2
# Project is smaller than first choice
# added to recBV4tnudHE7nfVe for a total of 1
# Project is smaller than first choice
# added to recPicjXoao4P1sYi for a total of 1
# added to recPicjXoao4P1sYi for a total of 2
# Project is smaller than first choice
# added to rec06vLugwlyiwKRJ for a total of 1
# Project is smaller than first choice
# Project is smaller than first choice
# added to recN5jfofjWSwSrRa for a total of 1
# added to recN5jfofjWSwSrRa for a total of 2
# Project is smaller than first choice
# added to recutheHfwlEcI8ea for a total of 1
# Project is smaller than first choice
# added to recx57nYAOmjMVbGr for a total of 1
# Project is smaller than first choice
# added to recGmUNTfNSu28VBj for a total of 1
# added to recGmUNTfNSu28VBj for a total of 2
# Project is smaller than first choice
# added to recJWZyyv8lPYjJQO for a total of 1
# added to recJWZyyv8lPYjJQO for a total of 2
# Project is smaller than first choice
# Project is smaller than first choice
# added to rec7dAEBa4xUKzry4 for a total of 1
# added to rec7dAEBa4xUKzry4 for a total of 2
# Project is smaller than first choice
# added to recPLBgRWjqTGjkTT for a total of 1
# Project is smaller than first choice
# Project is smaller than first choice
# added to recaqq7osXD44Agsm for a total of 1
# Project is smaller than first choice
# Project is smaller than first choice
# added to recQYxCYUTZeXbn4c for a total of 1
# Project is smaller than first choice
# added to rec5E1rwiK1cEhKkD for a total of 1
# added to rec5E1rwiK1cEhKkD for a total of 2
# added to rec5E1rwiK1cEhKkD for a total of 3
# Project is smaller than first choice
# added to recrRnxWgHOe94tH9 for a total of 1
# Project is smaller than first choice
# added to recKisQdoG2RR0QbF for a total of 1
# Project is smaller than first choice
# added to recmOjtldMMBt5Z3q for a total of 1
# Project is smaller than first choice
# added to recicI3vLpk1uPV3X for a total of 1
# added to recicI3vLpk1uPV3X for a total of 2
# Project is smaller than first choice
# added to recD59X42Aq9a6pkP for a total of 1
# Project is smaller than first choice
# added to rec3f1Ue3HYaUxSP9 for a total of 1
# Project is smaller than first choice
# added to recwK98F7v7iTAWH0 for a total of 1
# Project is smaller than first choice
# Project is smaller than first choice
# Project is smaller than first choice
# added to recVWbZ9jIbVX87z4 for a total of 1
# added to recVWbZ9jIbVX87z4 for a total of 2
# Project is smaller than first choice
# added to recC5xUEXAyBLMQZy for a total of 1
# Project is smaller than first choice
# Project is smaller than first choice
# added to reco0JFmpPeksCYPw for a total of 1
# Project is smaller than first choice
# Project is smaller than first choice
# added to recmHJqE2xmbys2XK for a total of 1
# Project is smaller than first choice
# added to recYyeMKK2jk9NWe3 for a total of 1
# added to recYyeMKK2jk9NWe3 for a total of 2
# Project is smaller than first choice
# added to reccOqh9jPOSV5pGx for a total of 1
# added to reccOqh9jPOSV5pGx for a total of 2
# Project is smaller than first choice
# added to recSsPUtEK3vdQQuZ for a total of 1
# [('rec4lUePnxyU7t8Fj', 4), ('recpNC7Da4rzGErs9', 5)]
# [('recMyYouPsBywy9YB', 4), ('rectBeG2SZPHSJsmJ', 6)]
# [('recABUMJ4tLNLUcke', 4)]
# [('reccSNGBy7PClX5or', 6)]
# [('recJFJ9KvQwu2glaB', 2)]
# [('rec1SKj39sBRlv6Sy', 3)]
# []
# []
# [('recOzpriyLtUiWldh', 4), ('recl3MvASkdNI4OzB', 4), ('recB1RQa6w7g9BfA5', 4)]
# [('reccIgkGxR5XfnEqF', 5), ('recrLVUtSoD8fyTMG', 6)]
# [('recJeFo3zFRAElbVZ', 4), ('recQfzcvaHNwTbkVc', 5)]
# [('reccKITK99zf57nkb', 2), ('recNtTiLlmeL7bVkR', 3)]
# [('recdnC6pFnV3aXYyB', 4), ('recdVlM35sPQPEKXM', 4)]
# [('recaom1BVLQxjLbwC', 5), ('reclSDbMZHgWEx0y4', 8)]
# [('recU4CQTz1BO3vr8y', 7)]
# [('recLuD3fjkd6ics32', 2), ('rectqXActzx5V22z8', 4)]
# []
# []
# [('rec3v0W6pkKWHImC6', 4), ('rec2mDFgkE10KsPhe', 5)]
# [('recqNrGzMq3unv9Ro', 3), ('rec6D741f4P3g5XL7', 5)]
# []
# [('rec0uKvrIqhMcnd2g', 7)]
# [('rec1feocrPEsyO8td', 4), ('recEr9g6aXdSF9HKi', 5)]
# []
# [('recnLwqgRhj4dmKCB', 3)]
# [('reckmxQZOoFzZU4Em', 4), ('reccESEUTCfUyGgSW', 5)]
# [('rectlSmSR4fF0xCzz', 5)]
# [('recNc0EaARHtpm101', 5)]
# [('reccS1PXmOubbUGEC', 2), ('recoXi249DwXUeBY9', 2)]
# []
# [('rec0sS1znKQHpVaJi', 3)]
# [('recvyTteXqv8ay6W4', 3), ('rectrMjo9Rt8HJxCD', 4), ('reclAP6mIg0zGsjDO', 5)]
# [('recgMCkXAiBMtgOg8', 4), ('reczzSomEXZz8dycY', 5)]
# []
# []
# [('recNdvqfrTPnNnvfo', 3), ('recd4xp9yzy9VBjuq', 4), ('recHOuHFq6cusbVeA', 4), ('reczIZ88bc0r3labo', 4), ('recHAVjbDnw71Pajs', 5)]
# []
# []
# [('recBbULwe6eIgreE7', 3), ('recCZ6Y1JbMjfxrIP', 4), ('rec7S1KMQY2v7YINI', 4)]
# []
# [('reczk9UgMAmoem0Wh', 3), ('reccCPmUGC5fYqZZJ', 3), ('recvvnnEhNzcaxk93', 3), ('recj4GnvLpo4cuEaj', 5)]
# [('recwuyOT77i03Pv3u', 4), ('rec10ubjfxTikUMzv', 5), ('recBY6Zt9diNb9yR0', 5)]
# [('rectyGRNK0lSATvHC', 3), ('recFkqJVZ8JvonPym', 4), ('recf0rM86KwVoTM7A', 4), ('recK1dK5pHcgu5UD0', 4), ('recAYXW8e6JqsuBUR', 4)]
# [('rec3cQopQfazDDQHp', 4)]
# [('recNK5WLSKp63MWPJ', 2), ('recB3x1xx3PeQKgHS', 3), ('recVXFe8vMJ91SVZK', 4)]
# []
# [('recCB6PtuHp6jNzbA', 1), ('recuVapZbFOV1oACg', 2), ('recaCrI1M0y5hJ6kW', 2), ('recypLsHn2qy09iGM', 3), ('rec0jwlbiLtd47ZGY', 3), ('recdgVEAMG3YWTHTx', 3), ('recqfXY4P0Gco0SUn', 4)]
# [('recnJY6pZjGK27AK2', 1), ('rec2vT6sALyZfYTcY', 3)]
# [('recrcMKs1SGdBfoL0', 1), ('recHuhlPXhvMzzlfo', 1), ('recNtTiLlmeL7bVkR', 2), ('recMPjlIcW52B9v1x', 3)]
# [('rec9yVFXavBXWcqbm', 1), ('recruT5RVW47aEoR8', 1), ('recUqWivkpmvme9mP', 1), ('recUKu4WDLsK5oX20', 3), ('rec1IWuE2zYSMf3yR', 4)]
# []
# []
# [('recD9RMWipZZgCHuU', 2), ('recB1RQa6w7g9BfA5', 2)]
# [('recIomO2SrUZ7dXWO', 1), ('rectBeG2SZPHSJsmJ', 3)]
# []
# []
# [('recEeX1t3CBAY5L4Y', 3), ('reccKI4Ib2CzUZr2G', 3)]
# [('recS61JqPEwgM7NqS', 2), ('recnoPS1Rv0JqPpsG', 3), ('rece38NStEc69yNwg', 3), ('recdG8EFVx4BT54fB', 4), ('recmhzPJmxkhDkQDq', 4)]
# [('reclvU2noVw62gC8f', 3), ('rec735tsb3S3sMM1z', 3), ('recw40v6wrRMDfLyu', 5)]
# [('recCBDmw2TJ0mCKaU', 2), ('recOg2PRBtq2Vpsxb', 2), ('recl1fMakkKOeucQD', 3), ('recIhjzPjxZ1tkKQa', 4)]
# []
# []
# []
# [('recQdqV4OR0BqTpdY', 1), ('recoB9S7eG2zKpRJh', 1), ('recOARkqUCepemNWr', 2), ('recPUtkmcMoD1nKGs', 4), ('recVxHvPFsbuseyCb', 4)]
# []
# []
# [('rec62wwL42I530oPi', 2), ('recfLNZxgSvHuZhr3', 4), ('recHl44UsYezIu3O1', 4)]
# []
# [('recA5zMoI3ZznORuH', 1), ('recfs6M6myfYJRADq', 2), ('recXiV8oVRvGLmOZg', 2), ('recAPGiN77jjO0dFG', 3), ('rec2mDFgkE10KsPhe', 4)]
# []
# [('rec3bHnH4b6gJh0gN', 3), ('recfgou774OwLi5SY', 3), ('recbUMGgekcZgxX1D', 4)]
# [('recmvYaQGM0lEBCzM', 2), ('recCyoY16cFxuRMpf', 2), ('recXq2PQMdbEO9Ofj', 3), ('reca2Fpp34seNsNrX', 4)]
# [('recPyIABPfDZuwUWJ', 2), ('recv8Sw4Tez6B19nb', 2), ('recmdfVQT5s79DLJB', 2), ('recT8tYf4FIy8Ehnf', 2), ('reccKZfSGpqVmsXMk', 3)]
# [('recWfz0FwSJQ0Bngs', 3), ('recrLVUtSoD8fyTMG', 4), ('recBGct7sgqyLAYfV', 4), ('recukxKShmeuOvzSg', 5)]
# [('recJnOYOYj5lYyQo7', 1), ('recIFwYH3Dy6PKHPn', 1), ('recRJt4YImXoqomqg', 3), ('recz4cwbg7MvPkGFN', 3), ('recev7Nb2kAykwY7U', 3), ('rec1QjmTl97iBr2mV', 4)]
# []
# []
# []
# []
# [('recdBiDy8JYog9hec', 1), ('recVXFe8vMJ91SVZK', 3), ('rec1ELbtakHmJyKUn', 3)]
# [('reckMsjTIEouJu3b6', 1), ('rec0jZ3rtcyY6euXE', 6)]
# []
# []
# []
# []
# [('recAJtx7mISQGfLPu', 2), ('recFkqJVZ8JvonPym', 2), ('recBY6Zt9diNb9yR0', 3), ('recrCklwiQwA1jncL', 3)]
# [('recaQtyUg5W1oJx3y', 1), ('recl8g9lDU62opdPH', 2), ('recf0rM86KwVoTM7A', 2), ('recGeO7hrlnMBVJsr', 4)]
# [('recj4GnvLpo4cuEaj', 1), ('recK1dK5pHcgu5UD0', 2), ('recVwfUc6FeARUn4m', 2), ('receDgGIU9GFSldjI', 2), ('recdy0EVnUhDo3SyY', 4)]
# [('recX3Cb5KV9NVGghB', 2)]
# [('recB7dyDC8ME6goHO', 1), ('recAYXW8e6JqsuBUR', 1), ('reclAP6mIg0zGsjDO', 2), ('recKw0PW7CZcLeFmF', 2), ('recT0CWkKcLPqZ8Nb', 3), ('recHAVjbDnw71Pajs', 3), ('reczIZ88bc0r3labo', 3)]
# []
# [('recqfXY4P0Gco0SUn', 1)]
# []
# []
# [('rec0jwlbiLtd47ZGY', 1), ('recUKu4WDLsK5oX20', 1)]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('recAPGiN77jjO0dFG', 2)]
# Uh oh!1
# Uh oh!2
# Uh oh!4
# Uh oh!4
# Uh oh!4
# Uh oh!4
# Uh oh!4
# Uh oh!5
# Uh oh!7
# Uh oh!8
# Uh oh!9
# Uh oh!9
# Uh oh!9
# Uh oh!10
# Uh oh!10
# Number of Students assigned: 258/258. Starting students: 284
# lol

# %%
# %load_ext blackcellmagic
